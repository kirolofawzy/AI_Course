# %%
import pandas as pd
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
df = pd.read_csv("../heart.csv")

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#spliting data to target and feature
x = df.drop('target', axis= 1)
y = df['target']

print(x.shape , y.shape)
# Out:
# (1025, 13) (1025,)

# %%
#spliting data to test and train
X_train, X_test, y_train, y_test = train_test_split(x,y , test_size=0.2, random_state=42)
print(X_train.shape, y_train.shape)
print(X_test.shape , y_test.shape)
# Out:
# (820, 13) (820,)
# (205, 13) (205,)

# %%
#repare logistic regression
log_reg = LogisticRegression(random_state=42 , max_iter=1000)
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
#prepare  SVM  model
SVM_Model = SVC(kernel='linear', random_state=42)
SVM_Model.fit(X_train , y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
#prepare KNN model
KNN_Model = KNeighborsClassifier(n_neighbors=2)
KNN_Model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
#prepare decision tree model
DT_Model = DecisionTreeClassifier(random_state=42)
DT_Model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
#prepare Random Forest Tree model
RF_Model = RandomForestClassifier(n_estimators=7,random_state=42)
RF_Model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=7, random_state=42)

# %%
#prepare Naive Bayes model
nb_Model = GaussianNB()
nb_Model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#prepare ANN model
NN_Model = keras.Sequential([
    keras.layers.Input(shape=(X_train.shape[1],)),
    keras.layers.BatchNormalization(),

    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dropout(0.4),
    keras.layers.BatchNormalization(),

    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.3),

    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(0.2),

    keras.layers.Dense(1, activation='sigmoid')
])

NN_Model.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history = NN_Model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=32,
    validation_split=0.2,
    callbacks=[EarlyStopping(patience=15, restore_best_weights=True)],
    verbose=1
)


test_loss, test_acc = NN_Model.evaluate(X_test, y_test, verbose=0)
print(f"the acc is : {test_acc *100}% and the test loss is : {test_loss *100}%")


predictions = NN_Model.predict(X_test)
results = (predictions > 0.5).astype(int)
# Out:
# Epoch 1/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.5899 - loss: 0.7765 - val_accuracy: 0.6646 - val_loss: 0.6168
# Epoch 2/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7790 - loss: 0.4565 - val_accuracy: 0.7378 - val_loss: 0.5592
# Epoch 3/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8430 - loss: 0.3762 - val_accuracy: 0.7500 - val_loss: 0.5379
# Epoch 4/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8460 - loss: 0.3416 - val_accuracy: 0.7500 - val_loss: 0.5115
# Epoch 5/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8460 - loss: 0.3479 - val_accuracy: 0.7744 - val_loss: 0.4990
# Epoch 6/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8765 - loss: 0.3380 - val_accuracy: 0.7561 - val_loss: 0.4925
# Epoch 7/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8567 - loss: 0.3257 - val_accuracy: 0.8232 - val_loss: 0.4699
# Epoch 8/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8750 - loss: 0.3103 - val_accuracy: 0.8354 - val_loss: 0.4406
# Epoch 9/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8704 - loss: 0.2948 - val_accuracy: 0.8354 - val_loss: 0.4175
# Epoch 10/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8704 - loss: 0.2929 - val_accuracy: 0.8415 - val_loss: 0.4121
# Epoch 11/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8857 - loss: 0.2710 - val_accuracy: 0.8476 - val_loss: 0.3920
# Epoch 12/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8826 - loss: 0.2807 - val_accuracy: 0.8720 - val_loss: 0.3764
# Epoch 13/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 267ms/step - accuracy: 0.8841 - loss: 0.2823 - val_accuracy: 0.8659 - val_loss: 0.3694
# Epoch 14/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8796 - loss: 0.2648 - val_accuracy: 0.8780 - val_loss: 0.3574
# Epoch 15/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8796 - loss: 0.2584 - val_accuracy: 0.8659 - val_loss: 0.3458
# Epoch 16/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8887 - loss: 0.2661 - val_accuracy: 0.8598 - val_loss: 0.3454
# Epoch 17/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8826 - loss: 0.2617 - val_accuracy: 0.8659 - val_loss: 0.3440
# Epoch 18/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9024 - loss: 0.2422 - val_accuracy: 0.8537 - val_loss: 0.3475
# Epoch 19/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8902 - loss: 0.2396 - val_accuracy: 0.8476 - val_loss: 0.3468
# Epoch 20/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8994 - loss: 0.2486 - val_accuracy: 0.8476 - val_loss: 0.3301
# Epoch 21/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8735 - loss: 0.2667 - val_accuracy: 0.8659 - val_loss: 0.3133
# Epoch 22/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8841 - loss: 0.2527 - val_accuracy: 0.8780 - val_loss: 0.3294
# Epoch 23/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9101 - loss: 0.2236 - val_accuracy: 0.8780 - val_loss: 0.3158
# Epoch 24/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9131 - loss: 0.2056 - val_accuracy: 0.8780 - val_loss: 0.3223
# Epoch 25/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9116 - loss: 0.2037 - val_accuracy: 0.8902 - val_loss: 0.3147
# Epoch 26/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9162 - loss: 0.1823 - val_accuracy: 0.8963 - val_loss: 0.2829
# Epoch 27/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9146 - loss: 0.1844 - val_accuracy: 0.9024 - val_loss: 0.2805
# Epoch 28/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9146 - loss: 0.2144 - val_accuracy: 0.8963 - val_loss: 0.2763
# Epoch 29/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9177 - loss: 0.2122 - val_accuracy: 0.9024 - val_loss: 0.2888
# Epoch 30/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8979 - loss: 0.2156 - val_accuracy: 0.8963 - val_loss: 0.2939
# Epoch 31/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9070 - loss: 0.2078 - val_accuracy: 0.8963 - val_loss: 0.2917
# Epoch 32/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9345 - loss: 0.1589 - val_accuracy: 0.9085 - val_loss: 0.2780
# Epoch 33/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9238 - loss: 0.1747 - val_accuracy: 0.9085 - val_loss: 0.2757
# Epoch 34/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9253 - loss: 0.1762 - val_accuracy: 0.9085 - val_loss: 0.2759
# Epoch 35/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9192 - loss: 0.1835 - val_accuracy: 0.9085 - val_loss: 0.2642
# Epoch 36/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9177 - loss: 0.2042 - val_accuracy: 0.9085 - val_loss: 0.2431
# Epoch 37/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9268 - loss: 0.1879 - val_accuracy: 0.9085 - val_loss: 0.2762
# Epoch 38/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9360 - loss: 0.1657 - val_accuracy: 0.9146 - val_loss: 0.3007
# Epoch 39/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9421 - loss: 0.1700 - val_accuracy: 0.9146 - val_loss: 0.2884
# Epoch 40/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9345 - loss: 0.1467 - val_accuracy: 0.9085 - val_loss: 0.2845
# Epoch 41/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9375 - loss: 0.1597 - val_accuracy: 0.9146 - val_loss: 0.2777
# Epoch 42/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9314 - loss: 0.1717 - val_accuracy: 0.9085 - val_loss: 0.2770
# Epoch 43/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9360 - loss: 0.1630 - val_accuracy: 0.9146 - val_loss: 0.2596
# Epoch 44/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9405 - loss: 0.1634 - val_accuracy: 0.9085 - val_loss: 0.2589
# Epoch 45/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9192 - loss: 0.1683 - val_accuracy: 0.9085 - val_loss: 0.2742
# Epoch 46/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9451 - loss: 0.1379 - val_accuracy: 0.9146 - val_loss: 0.2610
# Epoch 47/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9421 - loss: 0.1495 - val_accuracy: 0.9085 - val_loss: 0.2664
# Epoch 48/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9421 - loss: 0.1422 - val_accuracy: 0.9085 - val_loss: 0.2731
# Epoch 49/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9436 - loss: 0.1256 - val_accuracy: 0.9146 - val_loss: 0.2425
# Epoch 50/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9299 - loss: 0.1524 - val_accuracy: 0.9085 - val_loss: 0.2700
# Epoch 51/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9314 - loss: 0.1497 - val_accuracy: 0.9207 - val_loss: 0.2641
# Epoch 52/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9543 - loss: 0.1236 - val_accuracy: 0.9146 - val_loss: 0.2647
# Epoch 53/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9573 - loss: 0.1169 - val_accuracy: 0.9085 - val_loss: 0.2711
# Epoch 54/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9497 - loss: 0.1263 - val_accuracy: 0.9085 - val_loss: 0.2822
# Epoch 55/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9421 - loss: 0.1579 - val_accuracy: 0.9207 - val_loss: 0.2563
# Epoch 56/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9390 - loss: 0.1397 - val_accuracy: 0.9085 - val_loss: 0.2427
# Epoch 57/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9497 - loss: 0.1219 - val_accuracy: 0.9207 - val_loss: 0.2575
# Epoch 58/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9451 - loss: 0.1332 - val_accuracy: 0.9268 - val_loss: 0.2591
# Epoch 59/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9558 - loss: 0.1164 - val_accuracy: 0.9207 - val_loss: 0.2643
# Epoch 60/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9405 - loss: 0.1604 - val_accuracy: 0.9268 - val_loss: 0.2380
# Epoch 61/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9619 - loss: 0.1030 - val_accuracy: 0.9268 - val_loss: 0.2354
# Epoch 62/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9482 - loss: 0.1322 - val_accuracy: 0.9329 - val_loss: 0.2446
# Epoch 63/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9512 - loss: 0.1222 - val_accuracy: 0.9329 - val_loss: 0.2479
# Epoch 64/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9543 - loss: 0.1205 - val_accuracy: 0.9329 - val_loss: 0.2431
# Epoch 65/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9588 - loss: 0.1082 - val_accuracy: 0.9329 - val_loss: 0.2548
# Epoch 66/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9573 - loss: 0.1158 - val_accuracy: 0.9329 - val_loss: 0.2801
# Epoch 67/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9345 - loss: 0.1672 - val_accuracy: 0.9329 - val_loss: 0.2865
# Epoch 68/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9573 - loss: 0.1240 - val_accuracy: 0.9268 - val_loss: 0.2906
# Epoch 69/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9512 - loss: 0.0995 - val_accuracy: 0.9268 - val_loss: 0.2684
# Epoch 70/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9482 - loss: 0.1161 - val_accuracy: 0.9329 - val_loss: 0.2465
# Epoch 71/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9741 - loss: 0.0759 - val_accuracy: 0.9329 - val_loss: 0.2576
# Epoch 72/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9558 - loss: 0.1039 - val_accuracy: 0.9329 - val_loss: 0.2608
# Epoch 73/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9543 - loss: 0.1017 - val_accuracy: 0.9329 - val_loss: 0.2530
# Epoch 74/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9512 - loss: 0.1148 - val_accuracy: 0.9329 - val_loss: 0.2570
# Epoch 75/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9558 - loss: 0.1078 - val_accuracy: 0.9329 - val_loss: 0.2706
# Epoch 76/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9543 - loss: 0.1159 - val_accuracy: 0.9329 - val_loss: 0.2594
# the acc is : 93.65853667259216% and the test loss is : 21.57920151948929%
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step

# %%
Models_List = [log_reg , SVM_Model , KNN_Model, DT_Model ,RF_Model , nb_Model , NN_Model]
Models_Name = ['log_reg','SVM' , 'KNN','DT_Model','RF_Model' , 'nb_Model' , 'NN_Model']
Models_Prediction = [ log_reg.predict(X_test) , SVM_Model.predict(X_test) ,
                      KNN_Model.predict(X_test) , DT_Model.predict(X_test),
                      RF_Model.predict(X_test) , nb_Model.predict(X_test), results]

# %%
#spliting data to target and feature For GA
x_GA = df[['sex', 'cp', 'chol', 'oldpeak']]
y_GA = df['target']
print(x.shape , y.shape)
# Out:
# (1025, 13) (1025,)

# %%
#spliting data to test and train for GA
X_train_GA, X_test_GA, y_train_GA, y_test_GA = train_test_split(x_GA,y_GA , test_size=0.2, random_state=42)
print(X_train_GA.shape, y_train_GA.shape)
print(X_test_GA.shape , y_test_GA.shape)
# Out:
# (820, 4) (820,)
# (205, 4) (205,)

# %%
#prepare the logistic regression after GA
x_log_reg_GA = df[['sex', 'cp', 'trestbps', 'thalach', 'oldpeak', 'thal']]
y_log_reg_GA = df['target']
print(x.shape , y.shape)

#spliting data to test and train for GA
X_train_log_reg_GA, X_test_log_reg_GA, y_train_log_reg_GA, y_test_log_reg_GA = train_test_split(x_log_reg_GA,y_log_reg_GA , test_size=0.2, random_state=42)
print(X_train_log_reg_GA.shape, y_train_log_reg_GA.shape)
print(X_test_log_reg_GA.shape , X_test_log_reg_GA.shape)


#repare logistic regression for GA
log_reg_GA = LogisticRegression(random_state=42 , max_iter=1000)
log_reg_GA.fit(X_train_log_reg_GA, y_train_log_reg_GA)
# Out:
# (1025, 13) (1025,)
# (820, 6) (820,)
# (205, 6) (205, 6)
# LogisticRegression(max_iter=1000, random_state=42)

# %%
#prepare the SVM after GA
x_SVM_GA = df[['sex', 'cp', 'thalach', 'exang', 'oldpeak', 'thal']]
y_SVM_GA = df['target']
print(x.shape, y.shape)

#spliting data to test and train for GA
X_train_SVM_GA, X_test_SVM_GA, y_train_SVM_GA, y_test_SVM_GA = train_test_split(x_SVM_GA, y_SVM_GA, test_size=0.2,random_state=42)
print(X_train_SVM_GA.shape, y_train_SVM_GA.shape)
print(X_test_SVM_GA.shape, y_test_SVM_GA.shape)

#prepare  SVM  model for GA
SVM_Model_GA = SVC(kernel='linear', random_state=42)
SVM_Model_GA.fit(X_train_SVM_GA, y_train_SVM_GA)
# Out:
# (1025, 13) (1025,)
# (820, 6) (820,)
# (205, 6) (205,)
# SVC(kernel='linear', random_state=42)

# %%
x_KNN_GA = df[['sex', 'cp', 'fbs', 'thalach', 'oldpeak', 'ca', 'thal']]
y_KNN_GA = df['target']
print(x.shape , y.shape)

#spliting data to test and train for GA
X_train_KNN_GA, X_test_KNN_GA, y_train_KNN_GA, y_test_KNN_GA = train_test_split(x_KNN_GA,y_KNN_GA , test_size=0.2, random_state=42)
print(X_train_KNN_GA.shape, y_train_KNN_GA.shape)
print(X_test_KNN_GA.shape , y_test_KNN_GA.shape)

#prepare KNN model for GA
KNN_Model_GA = KNeighborsClassifier(n_neighbors=2)
KNN_Model_GA.fit(X_train_KNN_GA, y_train_KNN_GA)
# Out:
# (1025, 13) (1025,)
# (820, 7) (820,)
# (205, 7) (205,)
# KNeighborsClassifier(n_neighbors=2)

# %%
x_DT_GA = df[['age', 'fbs', 'thalach', 'oldpeak']]
y_DT_GA = df['target']
print(x.shape , y.shape)

#spliting data to test and train for GA
X_train_DT_GA, X_test_DT_GA, y_train_DT_GA, y_test_DT_GA = train_test_split(x_DT_GA,y_DT_GA , test_size=0.2, random_state=42)
print(X_train_DT_GA.shape, y_train_DT_GA.shape)
print(X_test_DT_GA.shape , y_test_DT_GA.shape)

#prepare decision tree model for GA
DT_Model_GA = DecisionTreeClassifier(random_state=42)
DT_Model_GA.fit(X_train_DT_GA, y_train_DT_GA)
# Out:
# (1025, 13) (1025,)
# (820, 4) (820,)
# (205, 4) (205,)
# DecisionTreeClassifier(random_state=42)

# %%
x_RF_GA = df[['sex', 'cp', 'chol', 'exang', 'oldpeak']]
y_RF_GA = df['target']
print(x.shape , y.shape)

#spliting data to test and train for GA
X_train_RF_GA, X_test_RF_GA, y_train_RF_GA, y_test_RF_GA = train_test_split(x_RF_GA,y_RF_GA , test_size=0.2, random_state=42)
print(X_train_RF_GA.shape, y_train_RF_GA.shape)
print(X_test_RF_GA.shape , y_test_RF_GA.shape)


#prepare Random Forest Tree model for GA
RF_Model_GA = RandomForestClassifier(n_estimators=7,random_state=42)
RF_Model_GA.fit(X_train_RF_GA, y_train_RF_GA)
# Out:
# (1025, 13) (1025,)
# (820, 5) (820,)
# (205, 5) (205,)
# RandomForestClassifier(n_estimators=7, random_state=42)

# %%
x_nb_GA = df[['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']]
y_nb_GA = df['target']
print(x.shape , y.shape)

#spliting data to test and train for GA
X_train_nb_GA, X_test_nb_GA, y_train_nb_GA, y_test_nb_GA = train_test_split(x_nb_GA,y_nb_GA , test_size=0.2, random_state=42)
print(X_train_nb_GA.shape, y_train_nb_GA.shape)
print(X_test_nb_GA.shape , y_test_nb_GA.shape)


#prepare Naive Bayes model for GA
nb_Model_GA = GaussianNB()
nb_Model_GA.fit(X_train_nb_GA, y_train_nb_GA)
# Out:
# (1025, 13) (1025,)
# (820, 8) (820,)
# (205, 8) (205,)
# GaussianNB()

# %%
x_ANN_GA = df[['age', 'cp', 'trestbps', 'restecg', 'exang', 'oldpeak', 'ca', 'thal']]
y_ANN_GA = df['target']
print(x.shape , y.shape)

#spliting data to test and train for GA
X_train_ANN_GA, X_test_ANN_GA, y_train_ANN_GA, y_test_ANN_GA = train_test_split(x_ANN_GA,y_ANN_GA , test_size=0.2, random_state=42)
print(X_train_ANN_GA.shape, y_train_ANN_GA.shape)
print(X_test_ANN_GA.shape , y_test_ANN_GA.shape)



#prepare ANN model  for GA
NN_Model_GA = keras.Sequential([
    keras.layers.Input(shape=(X_train_ANN_GA.shape[1],)),
    keras.layers.BatchNormalization(),

    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dropout(0.4),
    keras.layers.BatchNormalization(),

    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.3),

    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(0.2),

    keras.layers.Dense(1, activation='sigmoid')
])

NN_Model_GA.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history = NN_Model_GA.fit(
    X_train_ANN_GA, y_train_ANN_GA,
    epochs=200,
    batch_size=32,
    validation_split=0.2,
    callbacks=[EarlyStopping(patience=15, restore_best_weights=True)],
    verbose=1
)


test_loss, test_acc = NN_Model_GA.evaluate(X_test_ANN_GA, y_test_ANN_GA, verbose=0)
print(f"the acc is : {test_acc *100}% and the test loss is : {test_loss *100}%")


predictions = NN_Model_GA.predict(X_test_ANN_GA)
results_GA = (predictions > 0.5).astype(int)
# Out:
# (1025, 13) (1025,)
# (820, 8) (820,)
# (205, 8) (205,)
# Epoch 1/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.6372 - loss: 0.6970 - val_accuracy: 0.4817 - val_loss: 0.7688
# Epoch 2/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8140 - loss: 0.4525 - val_accuracy: 0.4817 - val_loss: 0.8517
# Epoch 3/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8232 - loss: 0.3974 - val_accuracy: 0.5244 - val_loss: 0.6882
# Epoch 4/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8323 - loss: 0.3922 - val_accuracy: 0.6098 - val_loss: 0.6373
# Epoch 5/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8384 - loss: 0.3708 - val_accuracy: 0.6280 - val_loss: 0.5931
# Epoch 6/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8430 - loss: 0.3395 - val_accuracy: 0.6829 - val_loss: 0.5685
# Epoch 7/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8399 - loss: 0.3428 - val_accuracy: 0.7378 - val_loss: 0.5243
# Epoch 8/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8445 - loss: 0.3587 - val_accuracy: 0.7561 - val_loss: 0.4956
# Epoch 9/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8537 - loss: 0.3428 - val_accuracy: 0.7744 - val_loss: 0.4804
# Epoch 10/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8598 - loss: 0.3340 - val_accuracy: 0.7866 - val_loss: 0.4660
# Epoch 11/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8567 - loss: 0.3189 - val_accuracy: 0.7866 - val_loss: 0.4438
# Epoch 12/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8704 - loss: 0.3020 - val_accuracy: 0.8171 - val_loss: 0.4252
# Epoch 13/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8598 - loss: 0.3449 - val_accuracy: 0.8171 - val_loss: 0.4137
# Epoch 14/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8765 - loss: 0.3073 - val_accuracy: 0.8171 - val_loss: 0.4021
# Epoch 15/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8628 - loss: 0.3149 - val_accuracy: 0.8110 - val_loss: 0.3955
# Epoch 16/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8780 - loss: 0.3072 - val_accuracy: 0.8110 - val_loss: 0.3925
# Epoch 17/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8704 - loss: 0.2945 - val_accuracy: 0.8293 - val_loss: 0.3833
# Epoch 18/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8735 - loss: 0.2967 - val_accuracy: 0.8232 - val_loss: 0.3780
# Epoch 19/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8811 - loss: 0.2805 - val_accuracy: 0.8537 - val_loss: 0.3750
# Epoch 20/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8872 - loss: 0.2620 - val_accuracy: 0.8354 - val_loss: 0.3731
# Epoch 21/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8841 - loss: 0.2829 - val_accuracy: 0.8354 - val_loss: 0.3727
# Epoch 22/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8902 - loss: 0.2738 - val_accuracy: 0.8415 - val_loss: 0.3649
# Epoch 23/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8979 - loss: 0.2655 - val_accuracy: 0.8537 - val_loss: 0.3613
# Epoch 24/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8918 - loss: 0.2681 - val_accuracy: 0.8415 - val_loss: 0.3608
# Epoch 25/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8643 - loss: 0.2753 - val_accuracy: 0.8659 - val_loss: 0.3561
# Epoch 26/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8765 - loss: 0.2658 - val_accuracy: 0.8537 - val_loss: 0.3386
# Epoch 27/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8826 - loss: 0.2681 - val_accuracy: 0.8720 - val_loss: 0.3405
# Epoch 28/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8963 - loss: 0.2526 - val_accuracy: 0.8476 - val_loss: 0.3444
# Epoch 29/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8918 - loss: 0.2810 - val_accuracy: 0.8659 - val_loss: 0.3426
# Epoch 30/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8689 - loss: 0.2616 - val_accuracy: 0.8720 - val_loss: 0.3292
# Epoch 31/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8826 - loss: 0.2608 - val_accuracy: 0.8720 - val_loss: 0.3250
# Epoch 32/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8780 - loss: 0.2680 - val_accuracy: 0.8720 - val_loss: 0.3187
# Epoch 33/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9024 - loss: 0.2303 - val_accuracy: 0.8780 - val_loss: 0.3188
# Epoch 34/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8963 - loss: 0.2336 - val_accuracy: 0.8780 - val_loss: 0.3269
# Epoch 35/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8963 - loss: 0.2546 - val_accuracy: 0.8780 - val_loss: 0.3383
# Epoch 36/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8948 - loss: 0.2356 - val_accuracy: 0.8780 - val_loss: 0.3459
# Epoch 37/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9009 - loss: 0.2439 - val_accuracy: 0.8841 - val_loss: 0.3250
# Epoch 38/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9146 - loss: 0.2335 - val_accuracy: 0.8841 - val_loss: 0.3127
# Epoch 39/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8887 - loss: 0.2629 - val_accuracy: 0.8720 - val_loss: 0.3210
# Epoch 40/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8979 - loss: 0.2422 - val_accuracy: 0.8720 - val_loss: 0.3081
# Epoch 41/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9162 - loss: 0.2155 - val_accuracy: 0.8659 - val_loss: 0.3217
# Epoch 42/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8918 - loss: 0.2538 - val_accuracy: 0.8841 - val_loss: 0.3078
# Epoch 43/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9040 - loss: 0.2341 - val_accuracy: 0.8780 - val_loss: 0.3107
# Epoch 44/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9055 - loss: 0.2129 - val_accuracy: 0.8780 - val_loss: 0.3122
# Epoch 45/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9314 - loss: 0.1943 - val_accuracy: 0.8902 - val_loss: 0.3019
# Epoch 46/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9009 - loss: 0.2304 - val_accuracy: 0.8963 - val_loss: 0.2876
# Epoch 47/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9040 - loss: 0.2213 - val_accuracy: 0.9024 - val_loss: 0.2801
# Epoch 48/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8963 - loss: 0.2255 - val_accuracy: 0.8902 - val_loss: 0.2949
# Epoch 49/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8918 - loss: 0.2590 - val_accuracy: 0.9085 - val_loss: 0.3045
# Epoch 50/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9131 - loss: 0.2128 - val_accuracy: 0.9024 - val_loss: 0.2852
# Epoch 51/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9101 - loss: 0.2139 - val_accuracy: 0.9024 - val_loss: 0.2913
# Epoch 52/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9177 - loss: 0.2302 - val_accuracy: 0.9085 - val_loss: 0.2813
# Epoch 53/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9253 - loss: 0.2012 - val_accuracy: 0.9085 - val_loss: 0.2741
# Epoch 54/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8979 - loss: 0.2454 - val_accuracy: 0.8841 - val_loss: 0.2852
# Epoch 55/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9040 - loss: 0.2197 - val_accuracy: 0.8780 - val_loss: 0.2983
# Epoch 56/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9345 - loss: 0.1811 - val_accuracy: 0.8963 - val_loss: 0.2985
# Epoch 57/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9040 - loss: 0.2226 - val_accuracy: 0.8902 - val_loss: 0.3133
# Epoch 58/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9146 - loss: 0.2123 - val_accuracy: 0.8902 - val_loss: 0.2934
# Epoch 59/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9085 - loss: 0.2141 - val_accuracy: 0.9024 - val_loss: 0.2818
# Epoch 60/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9284 - loss: 0.1698 - val_accuracy: 0.9024 - val_loss: 0.2936
# Epoch 61/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9101 - loss: 0.2114 - val_accuracy: 0.8963 - val_loss: 0.3004
# Epoch 62/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9131 - loss: 0.1907 - val_accuracy: 0.9085 - val_loss: 0.2820
# Epoch 63/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9070 - loss: 0.2078 - val_accuracy: 0.9024 - val_loss: 0.2764
# Epoch 64/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9040 - loss: 0.2176 - val_accuracy: 0.9024 - val_loss: 0.3001
# Epoch 65/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9146 - loss: 0.1952 - val_accuracy: 0.9085 - val_loss: 0.3155
# Epoch 66/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9207 - loss: 0.1985 - val_accuracy: 0.8963 - val_loss: 0.3030
# Epoch 67/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9238 - loss: 0.1778 - val_accuracy: 0.8902 - val_loss: 0.3108
# Epoch 68/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9192 - loss: 0.1937 - val_accuracy: 0.9085 - val_loss: 0.2994
# the acc is : 89.26829099655151% and the test loss is : 30.38678765296936%
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step

# %%
Models_List_GA = [log_reg_GA , SVM_Model_GA , KNN_Model_GA, DT_Model_GA ,RF_Model_GA , nb_Model_GA , NN_Model_GA]
Models_Name_GA = ['log_reg_GA','SVM_GA' , 'KNN_GA','DT_Model_GA','RF_Model_GA' , 'nb_Model_GA' , 'NN_Model_GA']
Models_Prediction_GA = [ log_reg_GA.predict(X_test_log_reg_GA) , SVM_Model_GA.predict(X_test_SVM_GA) ,
                      KNN_Model_GA.predict(X_test_KNN_GA) , DT_Model_GA.predict(X_test_DT_GA),
                      RF_Model_GA.predict(X_test_RF_GA) , nb_Model_GA.predict(X_test_nb_GA), results_GA]

# %%
results = []

for model, name, pred in zip(Models_List, Models_Name, Models_Prediction):
    accuracy = accuracy_score(y_test, pred) * 100
    precision = precision_score(y_test, pred, average='weighted', zero_division=0) * 100
    recall = recall_score(y_test, pred, average='weighted', zero_division=0) * 100
    f1 = f1_score(y_test, pred, average='weighted', zero_division=0) * 100

    results.append({
        'Model': name,
        'Accuracy ': f"{accuracy:.2f}",
        'Precision': f"{precision:.2f}",
        'Recall': f"{recall:.2f}",
        'F1-Score': f"{f1:.2f}"
    })

results_df = pd.DataFrame(results)

print("\n" + "="*70)
print("MODEL COMPARISON TABLE Before GA")
print("="*70)
print(results_df.to_string(index=False))



results = []

for model, name, pred in zip(Models_List_GA, Models_Name_GA, Models_Prediction_GA):
    accuracy = accuracy_score(y_test, pred) * 100
    precision = precision_score(y_test, pred, average='weighted', zero_division=0) * 100
    recall = recall_score(y_test, pred, average='weighted', zero_division=0) * 100
    f1 = f1_score(y_test, pred, average='weighted', zero_division=0) * 100

    results.append({
        'Model': name,
        'Accuracy ': f"{accuracy:.2f}",
        'Precision ': f"{precision:.2f}",
        'Recall': f"{recall:.2f}",
        'F1-Score': f"{f1:.2f}"
    })

results_df = pd.DataFrame(results)


print("\n" + "="*70)
print("MODEL COMPARISON TABLE After GA")
print("="*70)
print(results_df.to_string(index=False))
# Out:
# ======================================================================
# MODEL COMPARISON TABLE Before GA
# ======================================================================
#    Model Accuracy  Precision Recall F1-Score
#  log_reg     79.51     80.23  79.51    79.38
#      SVM     80.49     81.68  80.49    80.29
#      KNN     95.61     95.97  95.61    95.60
# DT_Model     98.54     98.58  98.54    98.54
# RF_Model     98.54     98.58  98.54    98.54
# nb_Model     80.00     81.05  80.00    79.82
# NN_Model     93.66     93.66  93.66    93.66
#
# ======================================================================
# MODEL COMPARISON TABLE After GA
# ======================================================================
#       Model Accuracy  Precision  Recall F1-Score
#  log_reg_GA     82.44      82.63  82.44    82.41
#      SVM_GA     82.44      82.74  82.44    82.39
#      KNN_GA     99.02      99.04  99.02    99.02
# DT_Model_GA    100.00     100.00 100.00   100.00
# RF_Model_GA    100.00     100.00 100.00   100.00
# nb_Model_GA     82.93      83.08  82.93    82.90
# NN_Model_GA     89.27      89.51  89.27    89.25

# %%
def print_detailed_report(y_true, y_pred, model_name=""):

    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)

    precision = precision_score(y_true, y_pred, average='binary')
    recall = recall_score(y_true, y_pred, average='binary')
    f1_score_val = f1_score(y_true, y_pred, average='binary')


    if cm.shape == (2, 2):
        TN, FP, FN, TP = cm.ravel()
        specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
    else:
        TN = cm[0, 0] if cm.shape[0] == 2 else "N/A"
        FP = cm[0, 1] if cm.shape[0] == 2 else "N/A"
        FN = cm[1, 0] if cm.shape[0] == 2 else "N/A"
        TP = cm[1, 1] if cm.shape[0] == 2 else "N/A"
        specificity = "N/A"


    print("\n" + "="*70)
    print(f"DETAILED EVALUATION REPORT - {model_name}")
    print("="*70)


    print("\nBASIC METRICS")
    print("-"*40)
    print(f"{'Accuracy:':<25} {accuracy:.4f} ({accuracy*100:.2f}%)")
    print(f"{'Precision:':<25} {precision:.4f}")
    print(f"{'Recall/Sensitivity:':<25} {recall:.4f}")
    print(f"{'Specificity:':<25} {specificity:.4f}")
    print(f"{'F1-Score:':<25} {f1_score_val:.4f}")


    print("\n CONFUSION MATRIX")
    print("-"*40)
    print(f"{'':<15} {'Predicted':^20}")
    print(f"{'':<15} {'No (0)':^10} {'Yes (1)':^10}")
    print("-"*45)
    print(f"{'Actual No (0)':<15} {TN:^10} {FP:^10}")
    print(f"{'Actual Yes (1)':<15} {FN:^10} {TP:^10}")


    print("\nCONFUSION MATRIX BREAKDOWN")
    print("-"*40)
    print(f"{'True Positive (TP):':<25} {TP:>4d} - Correctly predicted positive")
    print(f"{'True Negative (TN):':<25} {TN:>4d} - Correctly predicted negative")
    print(f"{'False Positive (FP):':<25} {FP:>4d} - False alarm (Type I Error)")
    print(f"{'False Negative (FN):':<25} {FN:>4d} - Missed case (Type II Error)")


    if isinstance(TP, int) and isinstance(TN, int):
        total = TP + TN + FP + FN
        print("\nRATES & PERCENTAGES")
        print("-"*40)
        print(f"{'Overall Accuracy Rate:':<25} {(TP + TN)/total:.2%}")
        print(f"{'Overall Error Rate:':<25} {(FP + FN)/total:.2%}")
        print(f"{'False Positive Rate:':<25} {FP/(FP + TN):.2%}" if (FP + TN) > 0 else f"{'False Positive Rate:':<25} 0.00%")
        print(f"{'False Negative Rate:':<25} {FN/(TP + FN):.2%}" if (TP + FN) > 0 else f"{'False Negative Rate:':<25} 0.00%")
        print(f"{'Positive Predictive Value:':<25} {precision:.2%}")
        print(f"{'Negative Predictive Value:':<25} {TN/(TN + FN):.2%}" if (TN + FN) > 0 else f"{'Negative Predictive Value:':<25} 0.00%")


    print("\nCOMPLETE CLASSIFICATION REPORT")
    print("-"*40)
    print(classification_report(y_true, y_pred, digits=4))


print("="*70)
print("MODEL COMPARISON AND EVALUATION")
print("="*70)

for model, name, pred in zip(Models_List, Models_Name, Models_Prediction):
    print_detailed_report(y_test, pred, name)
# Out:
# ======================================================================
# MODEL COMPARISON AND EVALUATION
# ======================================================================
#
# ======================================================================
# DETAILED EVALUATION REPORT - log_reg
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.7951 (79.51%)
# Precision:                0.7563
# Recall/Sensitivity:       0.8738
# Specificity:              0.7157
# F1-Score:                 0.8108
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)       73         29
# Actual Yes (1)      13         90
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         90 - Correctly predicted positive
# True Negative (TN):         73 - Correctly predicted negative
# False Positive (FP):        29 - False alarm (Type I Error)
# False Negative (FN):        13 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.8488    0.7157    0.7766       102
#            1     0.7563    0.8738    0.8108       103
#
#     accuracy                         0.7951       205
#    macro avg     0.8026    0.7947    0.7937       205
# weighted avg     0.8023    0.7951    0.7938       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - SVM
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.8049 (80.49%)
# Precision:                0.7561
# Recall/Sensitivity:       0.9029
# Specificity:              0.7059
# F1-Score:                 0.8230
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)       72         30
# Actual Yes (1)      10         93
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         93 - Correctly predicted positive
# True Negative (TN):         72 - Correctly predicted negative
# False Positive (FP):        30 - False alarm (Type I Error)
# False Negative (FN):        10 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.8780    0.7059    0.7826       102
#            1     0.7561    0.9029    0.8230       103
#
#     accuracy                         0.8049       205
#    macro avg     0.8171    0.8044    0.8028       205
# weighted avg     0.8168    0.8049    0.8029       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - KNN
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.9561 (95.61%)
# Precision:                1.0000
# Recall/Sensitivity:       0.9126
# Specificity:              1.0000
# F1-Score:                 0.9543
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)      102         0
# Actual Yes (1)      9          94
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         94 - Correctly predicted positive
# True Negative (TN):        102 - Correctly predicted negative
# False Positive (FP):         0 - False alarm (Type I Error)
# False Negative (FN):         9 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.9189    1.0000    0.9577       102
#            1     1.0000    0.9126    0.9543       103
#
#     accuracy                         0.9561       205
#    macro avg     0.9595    0.9563    0.9560       205
# weighted avg     0.9597    0.9561    0.9560       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - DT_Model
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.9854 (98.54%)
# Precision:                1.0000
# Recall/Sensitivity:       0.9709
# Specificity:              1.0000
# F1-Score:                 0.9852
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)      102         0
# Actual Yes (1)      3         100
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):        100 - Correctly predicted positive
# True Negative (TN):        102 - Correctly predicted negative
# False Positive (FP):         0 - False alarm (Type I Error)
# False Negative (FN):         3 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.9714    1.0000    0.9855       102
#            1     1.0000    0.9709    0.9852       103
#
#     accuracy                         0.9854       205
#    macro avg     0.9857    0.9854    0.9854       205
# weighted avg     0.9858    0.9854    0.9854       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - RF_Model
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.9854 (98.54%)
# Precision:                1.0000
# Recall/Sensitivity:       0.9709
# Specificity:              1.0000
# F1-Score:                 0.9852
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)      102         0
# Actual Yes (1)      3         100
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):        100 - Correctly predicted positive
# True Negative (TN):        102 - Correctly predicted negative
# False Positive (FP):         0 - False alarm (Type I Error)
# False Negative (FN):         3 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.9714    1.0000    0.9855       102
#            1     1.0000    0.9709    0.9852       103
#
#     accuracy                         0.9854       205
#    macro avg     0.9857    0.9854    0.9854       205
# weighted avg     0.9858    0.9854    0.9854       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - nb_Model
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.8000 (80.00%)
# Precision:                0.7541
# Recall/Sensitivity:       0.8932
# Specificity:              0.7059
# F1-Score:                 0.8178
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)       72         30
# Actual Yes (1)      11         92
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         92 - Correctly predicted positive
# True Negative (TN):         72 - Correctly predicted negative
# False Positive (FP):        30 - False alarm (Type I Error)
# False Negative (FN):        11 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.8675    0.7059    0.7784       102
#            1     0.7541    0.8932    0.8178       103
#
#     accuracy                         0.8000       205
#    macro avg     0.8108    0.7995    0.7981       205
# weighted avg     0.8105    0.8000    0.7982       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - NN_Model
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.9366 (93.66%)
# Precision:                0.9412
# Recall/Sensitivity:       0.9320
# Specificity:              0.9412
# F1-Score:                 0.9366
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)       96         6
# Actual Yes (1)      7          96
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         96 - Correctly predicted positive
# True Negative (TN):         96 - Correctly predicted negative
# False Positive (FP):         6 - False alarm (Type I Error)
# False Negative (FN):         7 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.9320    0.9412    0.9366       102
#            1     0.9412    0.9320    0.9366       103
#
#     accuracy                         0.9366       205
#    macro avg     0.9366    0.9366    0.9366       205
# weighted avg     0.9366    0.9366    0.9366       205

# %%
def print_detailed_report(y_true, y_pred, model_name=""):

    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)

    precision = precision_score(y_true, y_pred, average='binary')
    recall = recall_score(y_true, y_pred, average='binary')
    f1_score_val = f1_score(y_true, y_pred, average='binary')


    if cm.shape == (2, 2):
        TN, FP, FN, TP = cm.ravel()
        specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
    else:
        TN = cm[0, 0] if cm.shape[0] == 2 else "N/A"
        FP = cm[0, 1] if cm.shape[0] == 2 else "N/A"
        FN = cm[1, 0] if cm.shape[0] == 2 else "N/A"
        TP = cm[1, 1] if cm.shape[0] == 2 else "N/A"
        specificity = "N/A"


    print("\n" + "="*70)
    print(f"DETAILED EVALUATION REPORT - {model_name}")
    print("="*70)


    print("\nBASIC METRICS")
    print("-"*40)
    print(f"{'Accuracy:':<25} {accuracy:.4f} ({accuracy*100:.2f}%)")
    print(f"{'Precision:':<25} {precision:.4f}")
    print(f"{'Recall/Sensitivity:':<25} {recall:.4f}")
    print(f"{'Specificity:':<25} {specificity:.4f}")
    print(f"{'F1-Score:':<25} {f1_score_val:.4f}")


    print("\n CONFUSION MATRIX")
    print("-"*40)
    print(f"{'':<15} {'Predicted':^20}")
    print(f"{'':<15} {'No (0)':^10} {'Yes (1)':^10}")
    print("-"*45)
    print(f"{'Actual No (0)':<15} {TN:^10} {FP:^10}")
    print(f"{'Actual Yes (1)':<15} {FN:^10} {TP:^10}")


    print("\nCONFUSION MATRIX BREAKDOWN")
    print("-"*40)
    print(f"{'True Positive (TP):':<25} {TP:>4d} - Correctly predicted positive")
    print(f"{'True Negative (TN):':<25} {TN:>4d} - Correctly predicted negative")
    print(f"{'False Positive (FP):':<25} {FP:>4d} - False alarm (Type I Error)")
    print(f"{'False Negative (FN):':<25} {FN:>4d} - Missed case (Type II Error)")


    if isinstance(TP, int) and isinstance(TN, int):
        total = TP + TN + FP + FN
        print("\nRATES & PERCENTAGES")
        print("-"*40)
        print(f"{'Overall Accuracy Rate:':<25} {(TP + TN)/total:.2%}")
        print(f"{'Overall Error Rate:':<25} {(FP + FN)/total:.2%}")
        print(f"{'False Positive Rate:':<25} {FP/(FP + TN):.2%}" if (FP + TN) > 0 else f"{'False Positive Rate:':<25} 0.00%")
        print(f"{'False Negative Rate:':<25} {FN/(TP + FN):.2%}" if (TP + FN) > 0 else f"{'False Negative Rate:':<25} 0.00%")
        print(f"{'Positive Predictive Value:':<25} {precision:.2%}")
        print(f"{'Negative Predictive Value:':<25} {TN/(TN + FN):.2%}" if (TN + FN) > 0 else f"{'Negative Predictive Value:':<25} 0.00%")


    print("\nCOMPLETE CLASSIFICATION REPORT")
    print("-"*40)
    print(classification_report(y_true, y_pred, digits=4))


print("="*70)
print("MODEL COMPARISON AND EVALUATION after GA ")
print("="*70)

for model, name, pred in zip(Models_List_GA, Models_Name_GA, Models_Prediction_GA):
    print_detailed_report(y_test, pred, name)
# Out:
# ======================================================================
# MODEL COMPARISON AND EVALUATION after GA
# ======================================================================
#
# ======================================================================
# DETAILED EVALUATION REPORT - log_reg_GA
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.8244 (82.44%)
# Precision:                0.8018
# Recall/Sensitivity:       0.8641
# Specificity:              0.7843
# F1-Score:                 0.8318
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)       80         22
# Actual Yes (1)      14         89
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         89 - Correctly predicted positive
# True Negative (TN):         80 - Correctly predicted negative
# False Positive (FP):        22 - False alarm (Type I Error)
# False Negative (FN):        14 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.8511    0.7843    0.8163       102
#            1     0.8018    0.8641    0.8318       103
#
#     accuracy                         0.8244       205
#    macro avg     0.8264    0.8242    0.8241       205
# weighted avg     0.8263    0.8244    0.8241       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - SVM_GA
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.8244 (82.44%)
# Precision:                0.7965
# Recall/Sensitivity:       0.8738
# Specificity:              0.7745
# F1-Score:                 0.8333
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)       79         23
# Actual Yes (1)      13         90
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         90 - Correctly predicted positive
# True Negative (TN):         79 - Correctly predicted negative
# False Positive (FP):        23 - False alarm (Type I Error)
# False Negative (FN):        13 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.8587    0.7745    0.8144       102
#            1     0.7965    0.8738    0.8333       103
#
#     accuracy                         0.8244       205
#    macro avg     0.8276    0.8241    0.8239       205
# weighted avg     0.8274    0.8244    0.8239       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - KNN_GA
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.9902 (99.02%)
# Precision:                1.0000
# Recall/Sensitivity:       0.9806
# Specificity:              1.0000
# F1-Score:                 0.9902
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)      102         0
# Actual Yes (1)      2         101
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):        101 - Correctly predicted positive
# True Negative (TN):        102 - Correctly predicted negative
# False Positive (FP):         0 - False alarm (Type I Error)
# False Negative (FN):         2 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.9808    1.0000    0.9903       102
#            1     1.0000    0.9806    0.9902       103
#
#     accuracy                         0.9902       205
#    macro avg     0.9904    0.9903    0.9902       205
# weighted avg     0.9904    0.9902    0.9902       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - DT_Model_GA
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 1.0000 (100.00%)
# Precision:                1.0000
# Recall/Sensitivity:       1.0000
# Specificity:              1.0000
# F1-Score:                 1.0000
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)      102         0
# Actual Yes (1)      0         103
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):        103 - Correctly predicted positive
# True Negative (TN):        102 - Correctly predicted negative
# False Positive (FP):         0 - False alarm (Type I Error)
# False Negative (FN):         0 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       102
#            1     1.0000    1.0000    1.0000       103
#
#     accuracy                         1.0000       205
#    macro avg     1.0000    1.0000    1.0000       205
# weighted avg     1.0000    1.0000    1.0000       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - RF_Model_GA
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 1.0000 (100.00%)
# Precision:                1.0000
# Recall/Sensitivity:       1.0000
# Specificity:              1.0000
# F1-Score:                 1.0000
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)      102         0
# Actual Yes (1)      0         103
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):        103 - Correctly predicted positive
# True Negative (TN):        102 - Correctly predicted negative
# False Positive (FP):         0 - False alarm (Type I Error)
# False Negative (FN):         0 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       102
#            1     1.0000    1.0000    1.0000       103
#
#     accuracy                         1.0000       205
#    macro avg     1.0000    1.0000    1.0000       205
# weighted avg     1.0000    1.0000    1.0000       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - nb_Model_GA
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.8293 (82.93%)
# Precision:                0.8091
# Recall/Sensitivity:       0.8641
# Specificity:              0.7941
# F1-Score:                 0.8357
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)       81         21
# Actual Yes (1)      14         89
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         89 - Correctly predicted positive
# True Negative (TN):         81 - Correctly predicted negative
# False Positive (FP):        21 - False alarm (Type I Error)
# False Negative (FN):        14 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.8526    0.7941    0.8223       102
#            1     0.8091    0.8641    0.8357       103
#
#     accuracy                         0.8293       205
#    macro avg     0.8309    0.8291    0.8290       205
# weighted avg     0.8308    0.8293    0.8290       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - NN_Model_GA
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.8927 (89.27%)
# Precision:                0.8649
# Recall/Sensitivity:       0.9320
# Specificity:              0.8529
# F1-Score:                 0.8972
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)       87         15
# Actual Yes (1)      7          96
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         96 - Correctly predicted positive
# True Negative (TN):         87 - Correctly predicted negative
# False Positive (FP):        15 - False alarm (Type I Error)
# False Negative (FN):         7 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.9255    0.8529    0.8878       102
#            1     0.8649    0.9320    0.8972       103
#
#     accuracy                         0.8927       205
#    macro avg     0.8952    0.8925    0.8925       205
# weighted avg     0.8951    0.8927    0.8925       205
