# %%
import pandas as pd
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
df = pd.read_csv("../heart.csv")

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#spliting data to target and feature
x = df.drop('target', axis= 1)
y = df['target']

print(x.shape , y.shape)
# Out:
# (1025, 13) (1025,)

# %%
#spliting data to test and train
X_train, X_test, y_train, y_test = train_test_split(x,y , test_size=0.2, random_state=42)
print(X_train.shape, y_train.shape)
print(X_test.shape , y_test.shape)
# Out:
# (820, 13) (820,)
# (205, 13) (205,)

# %%
#repare logistic regression
log_reg = LogisticRegression(random_state=42 , max_iter=1000)
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
#prepare  SVM  model
SVM_Model = SVC(kernel='linear', random_state=42)
SVM_Model.fit(X_train , y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
#prepare KNN model
KNN_Model = KNeighborsClassifier(n_neighbors=2)
KNN_Model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
#prepare decision tree model
DT_Model = DecisionTreeClassifier(random_state=42)
DT_Model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
#prepare Random Forest Tree model
RF_Model = RandomForestClassifier(n_estimators=7,random_state=42)
RF_Model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=7, random_state=42)

# %%
#prepare Naive Bayes model
nb_Model = GaussianNB()
nb_Model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#prepare ANN model
NN_Model = keras.Sequential([
    keras.layers.Input(shape=(X_train.shape[1],)),
    keras.layers.BatchNormalization(),

    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dropout(0.4),
    keras.layers.BatchNormalization(),

    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.3),

    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(0.2),

    keras.layers.Dense(1, activation='sigmoid')
])

NN_Model.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history = NN_Model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=32,
    validation_split=0.2,
    callbacks=[EarlyStopping(patience=15, restore_best_weights=True)],
    verbose=1
)


test_loss, test_acc = NN_Model.evaluate(X_test, y_test, verbose=0)
print(f"the acc is : {test_acc *100}% and the test loss is : {test_loss *100}%")


predictions = NN_Model.predict(X_test)
results = (predictions > 0.5).astype(int)
# Out:
# Epoch 1/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.6235 - loss: 0.7094 - val_accuracy: 0.4756 - val_loss: 0.9826
# Epoch 2/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7637 - loss: 0.5019 - val_accuracy: 0.5061 - val_loss: 0.7054
# Epoch 3/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8079 - loss: 0.4242 - val_accuracy: 0.4939 - val_loss: 0.7624
# Epoch 4/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8399 - loss: 0.3795 - val_accuracy: 0.5610 - val_loss: 0.6280
# Epoch 5/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8476 - loss: 0.3526 - val_accuracy: 0.6707 - val_loss: 0.5653
# Epoch 6/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8323 - loss: 0.3595 - val_accuracy: 0.7866 - val_loss: 0.5144
# Epoch 7/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8659 - loss: 0.3372 - val_accuracy: 0.7988 - val_loss: 0.5009
# Epoch 8/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8567 - loss: 0.3385 - val_accuracy: 0.7988 - val_loss: 0.4682
# Epoch 9/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8689 - loss: 0.3144 - val_accuracy: 0.8110 - val_loss: 0.4448
# Epoch 10/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8796 - loss: 0.3198 - val_accuracy: 0.8110 - val_loss: 0.4264
# Epoch 11/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8613 - loss: 0.3150 - val_accuracy: 0.8171 - val_loss: 0.4067
# Epoch 12/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8872 - loss: 0.2657 - val_accuracy: 0.8232 - val_loss: 0.3830
# Epoch 13/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8735 - loss: 0.3019 - val_accuracy: 0.8293 - val_loss: 0.3667
# Epoch 14/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8780 - loss: 0.2811 - val_accuracy: 0.8598 - val_loss: 0.3552
# Epoch 15/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8872 - loss: 0.2812 - val_accuracy: 0.8598 - val_loss: 0.3381
# Epoch 16/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9619 - loss: 0.1010 - val_accuracy: 0.9329 - val_loss: 0.1784
# Epoch 81/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9573 - loss: 0.1012 - val_accuracy: 0.9451 - val_loss: 0.1743
# Epoch 82/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9543 - loss: 0.1114 - val_accuracy: 0.9329 - val_loss: 0.1954
# Epoch 83/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9421 - loss: 0.1489 - val_accuracy: 0.9329 - val_loss: 0.1819
# Epoch 84/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9604 - loss: 0.1020 - val_accuracy: 0.9268 - val_loss: 0.1785
# Epoch 85/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9680 - loss: 0.0882 - val_accuracy: 0.9329 - val_loss: 0.1807
# Epoch 86/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9665 - loss: 0.1009 - val_accuracy: 0.9329 - val_loss: 0.1964
# Epoch 87/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9604 - loss: 0.0992 - val_accuracy: 0.9268 - val_loss: 0.2042
# Epoch 88/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9451 - loss: 0.1157 - val_accuracy: 0.9268 - val_loss: 0.2069
# Epoch 89/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9634 - loss: 0.0913 - val_accuracy: 0.9329 - val_loss: 0.2125
# Epoch 90/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9512 - loss: 0.1029 - val_accuracy: 0.9329 - val_loss: 0.2110
# Epoch 91/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9649 - loss: 0.0974 - val_accuracy: 0.9329 - val_loss: 0.1947
# Epoch 92/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9787 - loss: 0.0779 - val_accuracy: 0.9329 - val_loss: 0.2052
# Epoch 93/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9771 - loss: 0.0691 - val_accuracy: 0.9329 - val_loss: 0.2056
# Epoch 94/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9680 - loss: 0.0961 - val_accuracy: 0.9268 - val_loss: 0.2393
# the acc is : 94.14634108543396% and the test loss is : 17.640073597431183%
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
Models_List = [log_reg , SVM_Model , KNN_Model, DT_Model ,RF_Model , nb_Model , NN_Model]
Models_Name = ['log_reg','SVM' , 'KNN','DT_Model','RF_Model' , 'nb_Model' , 'NN_Model']
Models_Prediction = [ log_reg.predict(X_test) , SVM_Model.predict(X_test) ,
                      KNN_Model.predict(X_test) , DT_Model.predict(X_test),
                      RF_Model.predict(X_test) , nb_Model.predict(X_test), results]

# %%
#spliting data to target and feature For GA
x_GA = df[['cp','chol']]
y_GA = df['target']
print(x.shape , y.shape)
# Out:
# (1025, 13) (1025,)

# %%
#spliting data to test and train for GA
X_train_GA, X_test_GA, y_train_GA, y_test_GA = train_test_split(x_GA,y_GA , test_size=0.2, random_state=42)
print(X_train_GA.shape, y_train_GA.shape)
print(X_test_GA.shape , y_test_GA.shape)
# Out:
# (820, 2) (820,)
# (205, 2) (205,)

# %%
#repare logistic regression for GA
log_reg_GA = LogisticRegression(random_state=42 , max_iter=1000)
log_reg_GA.fit(X_train_GA, y_train_GA)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
#prepare  SVM  model for GA
SVM_Model_GA = SVC(kernel='linear', random_state=42)
SVM_Model_GA.fit(X_train_GA , y_train_GA)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
#prepare KNN model for GA
KNN_Model_GA = KNeighborsClassifier(n_neighbors=2)
KNN_Model_GA.fit(X_train_GA, y_train_GA)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
#prepare decision tree model for GA
DT_Model_GA = DecisionTreeClassifier(random_state=42)
DT_Model_GA.fit(X_train_GA, y_train_GA)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
#prepare Random Forest Tree model for GA
RF_Model_GA = RandomForestClassifier(n_estimators=7,random_state=42)
RF_Model_GA.fit(X_train_GA, y_train_GA)
# Out:
# RandomForestClassifier(n_estimators=7, random_state=42)

# %%
#prepare Naive Bayes model for GA
nb_Model_GA = GaussianNB()
nb_Model_GA.fit(X_train_GA, y_train_GA)
# Out:
# GaussianNB()

# %%
#prepare ANN model  for GA
NN_Model_GA = keras.Sequential([
    keras.layers.Input(shape=(X_train_GA.shape[1],)),
    keras.layers.BatchNormalization(),

    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dropout(0.4),
    keras.layers.BatchNormalization(),

    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.3),

    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(0.2),

    keras.layers.Dense(1, activation='sigmoid')
])

NN_Model_GA.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history = NN_Model_GA.fit(
    X_train_GA, y_train_GA,
    epochs=200,
    batch_size=32,
    validation_split=0.2,
    callbacks=[EarlyStopping(patience=15, restore_best_weights=True)],
    verbose=1
)


test_loss, test_acc = NN_Model_GA.evaluate(X_test_GA, y_test_GA, verbose=0)
print(f"the acc is : {test_acc *100}% and the test loss is : {test_loss *100}%")


predictions = NN_Model_GA.predict(X_test_GA)
results_GA = (predictions > 0.5).astype(int)
# Out:
# Epoch 1/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6692 - loss: 0.6420 - val_accuracy: 0.4817 - val_loss: 0.6894
# Epoch 2/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7363 - loss: 0.6075 - val_accuracy: 0.6280 - val_loss: 0.6727
# Epoch 3/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7393 - loss: 0.6041 - val_accuracy: 0.7317 - val_loss: 0.6707
# Epoch 4/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7363 - loss: 0.5900 - val_accuracy: 0.7317 - val_loss: 0.6633
# Epoch 5/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7241 - loss: 0.5969 - val_accuracy: 0.7317 - val_loss: 0.6643
# Epoch 6/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7515 - loss: 0.5635 - val_accuracy: 0.7317 - val_loss: 0.6621
# Epoch 7/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7256 - loss: 0.5591 - val_accuracy: 0.7317 - val_loss: 0.6639
# Epoch 8/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7515 - loss: 0.5834 - val_accuracy: 0.7317 - val_loss: 0.6546
# Epoch 9/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7500 - loss: 0.5610 - val_accuracy: 0.7317 - val_loss: 0.6496
# Epoch 10/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7530 - loss: 0.5524 - val_accuracy: 0.7317 - val_loss: 0.6369
# Epoch 11/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7546 - loss: 0.5453 - val_accuracy: 0.7317 - val_loss: 0.6320
# Epoch 12/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7652 - loss: 0.5462 - val_accuracy: 0.7317 - val_loss: 0.6253
# Epoch 13/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7439 - loss: 0.5626 - val_accuracy: 0.7317 - val_loss: 0.6157
# Epoch 14/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7591 - loss: 0.5714 - val_accuracy: 0.7317 - val_loss: 0.6113
# Epoch 15/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7546 - loss: 0.5454 - val_accuracy: 0.7317 - val_loss: 0.5998
# Epoch 16/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7439 - loss: 0.5602 - val_accuracy: 0.7317 - val_loss: 0.5986
# Epoch 17/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7546 - loss: 0.5509 - val_accuracy: 0.7256 - val_loss: 0.5923
# Epoch 18/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7637 - loss: 0.5490 - val_accuracy: 0.7317 - val_loss: 0.5863
# Epoch 19/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7546 - loss: 0.5536 - val_accuracy: 0.7317 - val_loss: 0.5833
# Epoch 20/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7591 - loss: 0.5473 - val_accuracy: 0.7317 - val_loss: 0.5749
# Epoch 21/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7668 - loss: 0.5317 - val_accuracy: 0.7317 - val_loss: 0.5586
# Epoch 54/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7698 - loss: 0.5255 - val_accuracy: 0.7317 - val_loss: 0.5512
# Epoch 55/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7698 - loss: 0.5327 - val_accuracy: 0.7317 - val_loss: 0.5485
# Epoch 56/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7637 - loss: 0.5284 - val_accuracy: 0.7317 - val_loss: 0.5480
# Epoch 57/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7683 - loss: 0.5215 - val_accuracy: 0.7317 - val_loss: 0.5480
# Epoch 58/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7683 - loss: 0.5320 - val_accuracy: 0.7317 - val_loss: 0.5470
# Epoch 59/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7698 - loss: 0.5388 - val_accuracy: 0.7317 - val_loss: 0.5498
# the acc is : 75.12195110321045% and the test loss is : 58.77896547317505%
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
Models_List_GA = [log_reg_GA , SVM_Model_GA , KNN_Model_GA, DT_Model_GA ,RF_Model_GA , nb_Model_GA , NN_Model_GA]
Models_Name_GA = ['log_reg_GA','SVM_GA' , 'KNN_GA','DT_Model_GA','RF_Model_GA' , 'nb_Model_GA' , 'NN_Model_GA']
Models_Prediction_GA = [ log_reg_GA.predict(X_test_GA) , SVM_Model_GA.predict(X_test_GA) ,
                      KNN_Model_GA.predict(X_test_GA) , DT_Model_GA.predict(X_test_GA),
                      RF_Model_GA.predict(X_test_GA) , nb_Model_GA.predict(X_test_GA), results_GA]

# %%
results = []

for model, name, pred in zip(Models_List, Models_Name, Models_Prediction):
    accuracy = accuracy_score(y_test, pred) * 100
    precision = precision_score(y_test, pred, average='weighted', zero_division=0) * 100
    recall = recall_score(y_test, pred, average='weighted', zero_division=0) * 100
    f1 = f1_score(y_test, pred, average='weighted', zero_division=0) * 100

    results.append({
        'Model': name,
        'Accuracy ': f"{accuracy:.2f}",
        'Precision': f"{precision:.2f}",
        'Recall': f"{recall:.2f}",
        'F1-Score': f"{f1:.2f}"
    })

results_df = pd.DataFrame(results)

print("\n" + "="*70)
print("MODEL COMPARISON TABLE Before GA")
print("="*70)
print(results_df.to_string(index=False))



results = []

for model, name, pred in zip(Models_List_GA, Models_Name_GA, Models_Prediction_GA):
    accuracy = accuracy_score(y_test, pred) * 100
    precision = precision_score(y_test, pred, average='weighted', zero_division=0) * 100
    recall = recall_score(y_test, pred, average='weighted', zero_division=0) * 100
    f1 = f1_score(y_test, pred, average='weighted', zero_division=0) * 100

    results.append({
        'Model': name,
        'Accuracy ': f"{accuracy:.2f}",
        'Precision ': f"{precision:.2f}",
        'Recall': f"{recall:.2f}",
        'F1-Score': f"{f1:.2f}"
    })

results_df = pd.DataFrame(results)


print("\n" + "="*70)
print("MODEL COMPARISON TABLE After GA")
print("="*70)
print(results_df.to_string(index=False))
# Out:
# ======================================================================
# MODEL COMPARISON TABLE Before GA
# ======================================================================
#    Model Accuracy  Precision Recall F1-Score
#  log_reg     79.51     80.23  79.51    79.38
#      SVM     80.49     81.68  80.49    80.29
#      KNN     95.61     95.97  95.61    95.60
# DT_Model     98.54     98.58  98.54    98.54
# RF_Model     98.54     98.58  98.54    98.54
# nb_Model     80.00     81.05  80.00    79.82
# NN_Model     94.15     94.21  94.15    94.14
#
# ======================================================================
# MODEL COMPARISON TABLE After GA
# ======================================================================
#       Model Accuracy  Precision  Recall F1-Score
#  log_reg_GA     72.20      72.31  72.20    72.17
#      SVM_GA     74.63      74.79  74.63    74.60
#      KNN_GA     90.73      91.63  90.73    90.69
# DT_Model_GA     91.71      92.03  91.71    91.69
# RF_Model_GA     89.27      89.28  89.27    89.27
# nb_Model_GA     72.20      72.84  72.20    72.01
# NN_Model_GA     75.12      75.14  75.12    75.11

# %%
def print_detailed_report(y_true, y_pred, model_name=""):

    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)

    precision = precision_score(y_true, y_pred, average='binary')
    recall = recall_score(y_true, y_pred, average='binary')
    f1_score_val = f1_score(y_true, y_pred, average='binary')


    if cm.shape == (2, 2):
        TN, FP, FN, TP = cm.ravel()
        specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
    else:
        TN = cm[0, 0] if cm.shape[0] == 2 else "N/A"
        FP = cm[0, 1] if cm.shape[0] == 2 else "N/A"
        FN = cm[1, 0] if cm.shape[0] == 2 else "N/A"
        TP = cm[1, 1] if cm.shape[0] == 2 else "N/A"
        specificity = "N/A"


    print("\n" + "="*70)
    print(f"DETAILED EVALUATION REPORT - {model_name}")
    print("="*70)


    print("\nBASIC METRICS")
    print("-"*40)
    print(f"{'Accuracy:':<25} {accuracy:.4f} ({accuracy*100:.2f}%)")
    print(f"{'Precision:':<25} {precision:.4f}")
    print(f"{'Recall/Sensitivity:':<25} {recall:.4f}")
    print(f"{'Specificity:':<25} {specificity:.4f}")
    print(f"{'F1-Score:':<25} {f1_score_val:.4f}")


    print("\n CONFUSION MATRIX")
    print("-"*40)
    print(f"{'':<15} {'Predicted':^20}")
    print(f"{'':<15} {'No (0)':^10} {'Yes (1)':^10}")
    print("-"*45)
    print(f"{'Actual No (0)':<15} {TN:^10} {FP:^10}")
    print(f"{'Actual Yes (1)':<15} {FN:^10} {TP:^10}")


    print("\nCONFUSION MATRIX BREAKDOWN")
    print("-"*40)
    print(f"{'True Positive (TP):':<25} {TP:>4d} - Correctly predicted positive")
    print(f"{'True Negative (TN):':<25} {TN:>4d} - Correctly predicted negative")
    print(f"{'False Positive (FP):':<25} {FP:>4d} - False alarm (Type I Error)")
    print(f"{'False Negative (FN):':<25} {FN:>4d} - Missed case (Type II Error)")


    if isinstance(TP, int) and isinstance(TN, int):
        total = TP + TN + FP + FN
        print("\nRATES & PERCENTAGES")
        print("-"*40)
        print(f"{'Overall Accuracy Rate:':<25} {(TP + TN)/total:.2%}")
        print(f"{'Overall Error Rate:':<25} {(FP + FN)/total:.2%}")
        print(f"{'False Positive Rate:':<25} {FP/(FP + TN):.2%}" if (FP + TN) > 0 else f"{'False Positive Rate:':<25} 0.00%")
        print(f"{'False Negative Rate:':<25} {FN/(TP + FN):.2%}" if (TP + FN) > 0 else f"{'False Negative Rate:':<25} 0.00%")
        print(f"{'Positive Predictive Value:':<25} {precision:.2%}")
        print(f"{'Negative Predictive Value:':<25} {TN/(TN + FN):.2%}" if (TN + FN) > 0 else f"{'Negative Predictive Value:':<25} 0.00%")


    print("\nCOMPLETE CLASSIFICATION REPORT")
    print("-"*40)
    print(classification_report(y_true, y_pred, digits=4))


print("="*70)
print("MODEL COMPARISON AND EVALUATION")
print("="*70)

for model, name, pred in zip(Models_List, Models_Name, Models_Prediction):
    print_detailed_report(y_test, pred, name)
# Out:
# ======================================================================
# MODEL COMPARISON AND EVALUATION
# ======================================================================
#
# ======================================================================
# DETAILED EVALUATION REPORT - log_reg
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.7951 (79.51%)
# Precision:                0.7563
# Recall/Sensitivity:       0.8738
# Specificity:              0.7157
# F1-Score:                 0.8108
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)       73         29
# Actual Yes (1)      13         90
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         90 - Correctly predicted positive
# True Negative (TN):         73 - Correctly predicted negative
# False Positive (FP):        29 - False alarm (Type I Error)
# False Negative (FN):        13 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.8488    0.7157    0.7766       102
#            1     0.7563    0.8738    0.8108       103
#
#     accuracy                         0.7951       205
#    macro avg     0.8026    0.7947    0.7937       205
# weighted avg     0.8023    0.7951    0.7938       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - SVM
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.8049 (80.49%)
# Precision:                0.7561
# Recall/Sensitivity:       0.9029
# Specificity:              0.7059
# F1-Score:                 0.8230
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)       72         30
# Actual Yes (1)      10         93
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         93 - Correctly predicted positive
# True Negative (TN):         72 - Correctly predicted negative
# False Positive (FP):        30 - False alarm (Type I Error)
# False Negative (FN):        10 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.8780    0.7059    0.7826       102
#            1     0.7561    0.9029    0.8230       103
#
#     accuracy                         0.8049       205
#    macro avg     0.8171    0.8044    0.8028       205
# weighted avg     0.8168    0.8049    0.8029       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - KNN
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.9561 (95.61%)
# Precision:                1.0000
# Recall/Sensitivity:       0.9126
# Specificity:              1.0000
# F1-Score:                 0.9543
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)      102         0
# Actual Yes (1)      9          94
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         94 - Correctly predicted positive
# True Negative (TN):        102 - Correctly predicted negative
# False Positive (FP):         0 - False alarm (Type I Error)
# False Negative (FN):         9 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.9189    1.0000    0.9577       102
#            1     1.0000    0.9126    0.9543       103
#
#     accuracy                         0.9561       205
#    macro avg     0.9595    0.9563    0.9560       205
# weighted avg     0.9597    0.9561    0.9560       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - DT_Model
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.9854 (98.54%)
# Precision:                1.0000
# Recall/Sensitivity:       0.9709
# Specificity:              1.0000
# F1-Score:                 0.9852
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)      102         0
# Actual Yes (1)      3         100
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):        100 - Correctly predicted positive
# True Negative (TN):        102 - Correctly predicted negative
# False Positive (FP):         0 - False alarm (Type I Error)
# False Negative (FN):         3 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.9714    1.0000    0.9855       102
#            1     1.0000    0.9709    0.9852       103
#
#     accuracy                         0.9854       205
#    macro avg     0.9857    0.9854    0.9854       205
# weighted avg     0.9858    0.9854    0.9854       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - RF_Model
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.9854 (98.54%)
# Precision:                1.0000
# Recall/Sensitivity:       0.9709
# Specificity:              1.0000
# F1-Score:                 0.9852
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)      102         0
# Actual Yes (1)      3         100
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):        100 - Correctly predicted positive
# True Negative (TN):        102 - Correctly predicted negative
# False Positive (FP):         0 - False alarm (Type I Error)
# False Negative (FN):         3 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.9714    1.0000    0.9855       102
#            1     1.0000    0.9709    0.9852       103
#
#     accuracy                         0.9854       205
#    macro avg     0.9857    0.9854    0.9854       205
# weighted avg     0.9858    0.9854    0.9854       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - nb_Model
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.8000 (80.00%)
# Precision:                0.7541
# Recall/Sensitivity:       0.8932
# Specificity:              0.7059
# F1-Score:                 0.8178
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)       72         30
# Actual Yes (1)      11         92
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         92 - Correctly predicted positive
# True Negative (TN):         72 - Correctly predicted negative
# False Positive (FP):        30 - False alarm (Type I Error)
# False Negative (FN):        11 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.8675    0.7059    0.7784       102
#            1     0.7541    0.8932    0.8178       103
#
#     accuracy                         0.8000       205
#    macro avg     0.8108    0.7995    0.7981       205
# weighted avg     0.8105    0.8000    0.7982       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - NN_Model
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.9415 (94.15%)
# Precision:                0.9596
# Recall/Sensitivity:       0.9223
# Specificity:              0.9608
# F1-Score:                 0.9406
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)       98         4
# Actual Yes (1)      8          95
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         95 - Correctly predicted positive
# True Negative (TN):         98 - Correctly predicted negative
# False Positive (FP):         4 - False alarm (Type I Error)
# False Negative (FN):         8 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.9245    0.9608    0.9423       102
#            1     0.9596    0.9223    0.9406       103
#
#     accuracy                         0.9415       205
#    macro avg     0.9421    0.9416    0.9415       205
# weighted avg     0.9421    0.9415    0.9414       205

# %%
def print_detailed_report(y_true, y_pred, model_name=""):

    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)

    precision = precision_score(y_true, y_pred, average='binary')
    recall = recall_score(y_true, y_pred, average='binary')
    f1_score_val = f1_score(y_true, y_pred, average='binary')


    if cm.shape == (2, 2):
        TN, FP, FN, TP = cm.ravel()
        specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
    else:
        TN = cm[0, 0] if cm.shape[0] == 2 else "N/A"
        FP = cm[0, 1] if cm.shape[0] == 2 else "N/A"
        FN = cm[1, 0] if cm.shape[0] == 2 else "N/A"
        TP = cm[1, 1] if cm.shape[0] == 2 else "N/A"
        specificity = "N/A"


    print("\n" + "="*70)
    print(f"DETAILED EVALUATION REPORT - {model_name}")
    print("="*70)


    print("\nBASIC METRICS")
    print("-"*40)
    print(f"{'Accuracy:':<25} {accuracy:.4f} ({accuracy*100:.2f}%)")
    print(f"{'Precision:':<25} {precision:.4f}")
    print(f"{'Recall/Sensitivity:':<25} {recall:.4f}")
    print(f"{'Specificity:':<25} {specificity:.4f}")
    print(f"{'F1-Score:':<25} {f1_score_val:.4f}")


    print("\n CONFUSION MATRIX")
    print("-"*40)
    print(f"{'':<15} {'Predicted':^20}")
    print(f"{'':<15} {'No (0)':^10} {'Yes (1)':^10}")
    print("-"*45)
    print(f"{'Actual No (0)':<15} {TN:^10} {FP:^10}")
    print(f"{'Actual Yes (1)':<15} {FN:^10} {TP:^10}")


    print("\nCONFUSION MATRIX BREAKDOWN")
    print("-"*40)
    print(f"{'True Positive (TP):':<25} {TP:>4d} - Correctly predicted positive")
    print(f"{'True Negative (TN):':<25} {TN:>4d} - Correctly predicted negative")
    print(f"{'False Positive (FP):':<25} {FP:>4d} - False alarm (Type I Error)")
    print(f"{'False Negative (FN):':<25} {FN:>4d} - Missed case (Type II Error)")


    if isinstance(TP, int) and isinstance(TN, int):
        total = TP + TN + FP + FN
        print("\nRATES & PERCENTAGES")
        print("-"*40)
        print(f"{'Overall Accuracy Rate:':<25} {(TP + TN)/total:.2%}")
        print(f"{'Overall Error Rate:':<25} {(FP + FN)/total:.2%}")
        print(f"{'False Positive Rate:':<25} {FP/(FP + TN):.2%}" if (FP + TN) > 0 else f"{'False Positive Rate:':<25} 0.00%")
        print(f"{'False Negative Rate:':<25} {FN/(TP + FN):.2%}" if (TP + FN) > 0 else f"{'False Negative Rate:':<25} 0.00%")
        print(f"{'Positive Predictive Value:':<25} {precision:.2%}")
        print(f"{'Negative Predictive Value:':<25} {TN/(TN + FN):.2%}" if (TN + FN) > 0 else f"{'Negative Predictive Value:':<25} 0.00%")


    print("\nCOMPLETE CLASSIFICATION REPORT")
    print("-"*40)
    print(classification_report(y_true, y_pred, digits=4))


print("="*70)
print("MODEL COMPARISON AND EVALUATION after GA ")
print("="*70)

for model, name, pred in zip(Models_List_GA, Models_Name_GA, Models_Prediction_GA):
    print_detailed_report(y_test, pred, name)
# Out:
# ======================================================================
# MODEL COMPARISON AND EVALUATION after GA
# ======================================================================
#
# ======================================================================
# DETAILED EVALUATION REPORT - log_reg_GA
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.7220 (72.20%)
# Precision:                0.7396
# Recall/Sensitivity:       0.6893
# Specificity:              0.7549
# F1-Score:                 0.7136
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)       77         25
# Actual Yes (1)      32         71
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         71 - Correctly predicted positive
# True Negative (TN):         77 - Correctly predicted negative
# False Positive (FP):        25 - False alarm (Type I Error)
# False Negative (FN):        32 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.7064    0.7549    0.7299       102
#            1     0.7396    0.6893    0.7136       103
#
#     accuracy                         0.7220       205
#    macro avg     0.7230    0.7221    0.7217       205
# weighted avg     0.7231    0.7220    0.7217       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - SVM_GA
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.7463 (74.63%)
# Precision:                0.7684
# Recall/Sensitivity:       0.7087
# Specificity:              0.7843
# F1-Score:                 0.7374
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)       80         22
# Actual Yes (1)      30         73
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         73 - Correctly predicted positive
# True Negative (TN):         80 - Correctly predicted negative
# False Positive (FP):        22 - False alarm (Type I Error)
# False Negative (FN):        30 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.7273    0.7843    0.7547       102
#            1     0.7684    0.7087    0.7374       103
#
#     accuracy                         0.7463       205
#    macro avg     0.7478    0.7465    0.7460       205
# weighted avg     0.7479    0.7463    0.7460       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - KNN_GA
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.9073 (90.73%)
# Precision:                0.9773
# Recall/Sensitivity:       0.8350
# Specificity:              0.9804
# F1-Score:                 0.9005
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)      100         2
# Actual Yes (1)      17         86
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         86 - Correctly predicted positive
# True Negative (TN):        100 - Correctly predicted negative
# False Positive (FP):         2 - False alarm (Type I Error)
# False Negative (FN):        17 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.8547    0.9804    0.9132       102
#            1     0.9773    0.8350    0.9005       103
#
#     accuracy                         0.9073       205
#    macro avg     0.9160    0.9077    0.9069       205
# weighted avg     0.9163    0.9073    0.9069       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - DT_Model_GA
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.9171 (91.71%)
# Precision:                0.9574
# Recall/Sensitivity:       0.8738
# Specificity:              0.9608
# F1-Score:                 0.9137
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)       98         4
# Actual Yes (1)      13         90
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         90 - Correctly predicted positive
# True Negative (TN):         98 - Correctly predicted negative
# False Positive (FP):         4 - False alarm (Type I Error)
# False Negative (FN):        13 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.8829    0.9608    0.9202       102
#            1     0.9574    0.8738    0.9137       103
#
#     accuracy                         0.9171       205
#    macro avg     0.9202    0.9173    0.9169       205
# weighted avg     0.9203    0.9171    0.9169       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - RF_Model_GA
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.8927 (89.27%)
# Precision:                0.8857
# Recall/Sensitivity:       0.9029
# Specificity:              0.8824
# F1-Score:                 0.8942
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)       90         12
# Actual Yes (1)      10         93
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         93 - Correctly predicted positive
# True Negative (TN):         90 - Correctly predicted negative
# False Positive (FP):        12 - False alarm (Type I Error)
# False Negative (FN):        10 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.9000    0.8824    0.8911       102
#            1     0.8857    0.9029    0.8942       103
#
#     accuracy                         0.8927       205
#    macro avg     0.8929    0.8926    0.8927       205
# weighted avg     0.8928    0.8927    0.8927       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - nb_Model_GA
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.7220 (72.20%)
# Precision:                0.7674
# Recall/Sensitivity:       0.6408
# Specificity:              0.8039
# F1-Score:                 0.6984
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)       82         20
# Actual Yes (1)      37         66
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         66 - Correctly predicted positive
# True Negative (TN):         82 - Correctly predicted negative
# False Positive (FP):        20 - False alarm (Type I Error)
# False Negative (FN):        37 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.6891    0.8039    0.7421       102
#            1     0.7674    0.6408    0.6984       103
#
#     accuracy                         0.7220       205
#    macro avg     0.7283    0.7223    0.7202       205
# weighted avg     0.7284    0.7220    0.7201       205
#
#
# ======================================================================
# DETAILED EVALUATION REPORT - NN_Model_GA
# ======================================================================
#
# BASIC METRICS
# ----------------------------------------
# Accuracy:                 0.7512 (75.12%)
# Precision:                0.7453
# Recall/Sensitivity:       0.7670
# Specificity:              0.7353
# F1-Score:                 0.7560
#
#  CONFUSION MATRIX
# ----------------------------------------
#                      Predicted
#                   No (0)    Yes (1)
# ---------------------------------------------
# Actual No (0)       75         27
# Actual Yes (1)      24         79
#
# CONFUSION MATRIX BREAKDOWN
# ----------------------------------------
# True Positive (TP):         79 - Correctly predicted positive
# True Negative (TN):         75 - Correctly predicted negative
# False Positive (FP):        27 - False alarm (Type I Error)
# False Negative (FN):        24 - Missed case (Type II Error)
#
# COMPLETE CLASSIFICATION REPORT
# ----------------------------------------
#               precision    recall  f1-score   support
#
#            0     0.7576    0.7353    0.7463       102
#            1     0.7453    0.7670    0.7560       103
#
#     accuracy                         0.7512       205
#    macro avg     0.7514    0.7511    0.7511       205
# weighted avg     0.7514    0.7512    0.7511       205
